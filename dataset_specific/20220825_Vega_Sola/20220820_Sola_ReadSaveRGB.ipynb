# %%
import numpy as np
import skimage.io
import matplotlib.pyplot as plt
import pathlib
import hyspec_io, image_render
# import matplotlib.colors
# import tqdm
# import skimage.exposure

# import sklearn.metrics
# import spectral

# %%
hyspec_base = pathlib.Path('/media/mha114/Massimal/Vega_Sola/Hyperspectral/20220823/Area/2a_Rrs')
rgb_base = pathlib.Path('/media/mha114/Massimal/Vega_Sola/Hyperspectral/20220823/Area/2b_Rrs_RGB')
subfolders = ['Coast1','Coast2','Coast3','Sound1','Sound2','Sound3a','Sound3b']

hyspec_folders = [hyspec_base / folder for folder in subfolders]
rgb_folders = [rgb_base / folder for folder in subfolders]

# %%
# Loop through all folders and images and create percentile stretched RGB image
for hyspec_folder,rgb_folder in zip(hyspec_folders,rgb_folders):
    print(f'Folder {hyspec_folder.name}')
    hyspec_paths = [pathlib.Path(image_path) for image_path in sorted(hyspec_folder.glob('*.hdr'))]
    for hyspec_path in hyspec_paths:
        print(f'   Image {hyspec_path.name}')
        (image,_,_,_) = hyspec_io.load_envi_image(hyspec_path, rgb_only=True)
        skimage.io.imsave(rgb_folder / (hyspec_path.stem + '.png'),
                          np.uint8(image_render.percentile_stretch(image)*255),
                          check_contrast=False)
# Out:
# Folder Coast1
#    Image Vega_SolaNW_Coast1_Pika_L_1-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_10-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_11-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_12-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_13-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_14-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_15-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_16-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_17-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_18-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_19-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_2-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_20-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_21-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_22-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_23-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_24-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_25-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_26-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_27-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_28-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_29-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_3-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_30-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_31-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_4-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_5-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_6-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_7-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_8-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast1_Pika_L_9-Crop Wavelengths.bip.hdr
# Folder Coast2
#    Image Vega_SolaNW_Coast2_Pika_L_1-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_10-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_11-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_12-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_13-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_14-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_15-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_16-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_17-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_18-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_19-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_2-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_20-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_21-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_22-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_23-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_24-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_25-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_26-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_27-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_28-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_29-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_3-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_30-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_31-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_4-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_5-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast2_Pika_L_6-Crop Wavelengths.bip.hdr
# Folder Coast3
#    Image Vega_SolaNW_Coast3_Pika_L_1-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_10-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_11-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_12-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_13-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_14-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_15-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_16-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_17-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_18-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_19-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_2-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_20-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_21-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_22-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_23-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_24-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_25-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_26-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_27-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_28-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_3-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_4-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_5-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_6-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_7-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_8-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Coast3_Pika_L_9-Crop Wavelengths.bip.hdr
# Folder Sound1
#    Image Vega_SolaNW_Sound1_Pika_L_1-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_10-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_11-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_12-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_13-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_14-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_15-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_16-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_17-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_18-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_19-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_2-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_20-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_21-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_22-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_23-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_24-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_25-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_26-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_27-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_28-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_29-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_3-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_4-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_5-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_6-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_7-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_8-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound1_Pika_L_9-Crop Wavelengths.bip.hdr
# Folder Sound2
#    Image Vega_SolaNW_Sound2_Pika_L_1-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_10-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_11-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_12-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_13-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_14-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_15-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_16-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_17-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_18-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_19-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_2-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_20-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_21-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_22-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_23-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_24-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_25-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_26-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_27-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_28-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_29-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_3-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_30-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_31-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_32-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_4-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_5-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_6-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_7-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_8-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound2_Pika_L_9-Crop Wavelengths.bip.hdr
# Folder Sound3a
#    Image Vega_SolaNW_Sound3a_Pika_L_1-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_10-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_11-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_12-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_13-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_14-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_15-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_16-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_17-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_18-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_19-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_2-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_20-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_21-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_22-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_23-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_24-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_25-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_26-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_27-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_28-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_29-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_3-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_30-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_4-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_5-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_6-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_7-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_8-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3a_Pika_L_9-Crop Wavelengths.bip.hdr
# Folder Sound3b
#    Image Vega_SolaNW_Sound3b_Pika_L_1-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_10-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_11-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_12-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_13-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_14-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_15-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_16-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_17-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_18-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_19-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_2-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_20-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_21-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_22-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_23-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_24-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_25-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_26-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_27-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_28-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_3-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_4-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_5-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_6-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_7-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_8-Crop Wavelengths.bip.hdr
#    Image Vega_SolaNW_Sound3b_Pika_L_9-Crop Wavelengths.bip.hdr
