# %%
import tensorflow as tf
import numpy as np
import skimage.io
import matplotlib.pyplot as plt
from pathlib import Path
import tqdm
from massimal import image_render
import matplotlib.pyplot as plt

# %%
# Paths
pca_tile_dataset_path = Path('/home/mha114/data/massimal/vega_sola/hyperspec/datasets/pca_images/pca_images_log_rrs_v1/train_val_tiles/vega_sola_log_rrs_pca5_tiles/')

# %%
# Open dataset
dataset = tf.data.experimental.load(str(pca_tile_dataset_path))

# %%
# for pca_tile,label_tile,im_name in dataset.skip(1100).take(10).as_numpy_iterator():
for pca_tile,label_tile,im_name in dataset.skip(2100).take(10).as_numpy_iterator():
    #print(pca_tile.shape)
    #print(label_tile.shape)
    print(im_name)
    fig,ax = plt.subplots(ncols=5,figsize=(12,6))
    for i in range(5):
        im = ax[i].imshow(pca_tile[:,:,i],cmap='gray')
        ax[i].set_xticks([])
        ax[i].set_yticks([])
        plt.colorbar(im,ax=ax[i],orientation='horizontal')
    plt.show()
    
    plt.imshow(label_tile,vmin=0,vmax=8)
    plt.colorbar()
    plt.show()
# Out:
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
# b'Vega_SolaNW_Coast3_Pika_L_2'
