# %%
import tensorflow as tf
import hyspec_cnn
# Out:
# 2023-05-30 16:28:22.058070: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Paths
# unet_model_path = '/media/mha114/Massimal/Vega_Sola/Hyperspectral/20220823/Area/M_UnetModels/Depth2_Balanced/unet_model.depth2.epoch34-loss0.036197-acc0.834.hdf5'
unet_fig_save_path = '/home/mha114/Dropbox/UiT/Massimal/Konferanser/IGARSS2023/Paper/Figures/unet.png'
unet_fig_save_path_shapes = '/home/mha114/Dropbox/UiT/Massimal/Konferanser/IGARSS2023/Paper/Figures/unet_with_shapes.png'

# %%
# Load UNet model 
# unet = tf.keras.models.load_model(unet_model_path)

# %%
# Parameters
OUTPUT_CHANNELS = 8
BATCH_SIZE = 8
DEPTH = 2

# %%
# Create the U-Net model
unet = hyspec_cnn.unet(input_channels=8,
                       output_channels=OUTPUT_CHANNELS,
                       first_layer_channels=32,
                       depth = DEPTH,
               )
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_image (InputLayer)       [(None, None, None,  0           []
#                                  8)]
#
#  augmentation (Sequential)      (None, None, None,   0           ['input_image[0][0]']
#                                 8)
#
#  initial_convolution (Conv2D)   (None, None, None,   2336        ['augmentation[0][0]']
#                                 32)
#
#  downsamp_res_1/2 (Sequential)  (None, None, None,   33024       ['initial_convolution[0][0]']
#                                 64)
#
#  downsamp_res_1/4 (Sequential)  (None, None, None,   131584      ['downsamp_res_1/2[0][0]']
#                                 128)
#
#  upsamp_res_1/2 (Sequential)    (None, None, None,   131328      ['downsamp_res_1/4[0][0]']
#                                 64)
#
# ...

# %%
tf.keras.utils.plot_model(unet,show_shapes=False,to_file=unet_fig_save_path,dpi=300)

# %%
tf.keras.utils.plot_model(unet,show_shapes=True,rankdir='TB',to_file=unet_fig_save_path_shapes,dpi=300)

# %%
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_image (InputLayer)       [(None, None, None,  0           []
#                                  8)]
#
#  augmentation (Sequential)      (None, None, None,   0           ['input_image[0][0]']
#                                 8)
#
#  initial_convolution (Conv2D)   (None, None, None,   2336        ['augmentation[0][0]']
#                                 32)
#
#  downsamp_res_1/2 (Sequential)  (None, None, None,   33024       ['initial_convolution[0][0]']
#                                 64)
#
#  downsamp_res_1/4 (Sequential)  (None, None, None,   131584      ['downsamp_res_1/2[0][0]']
#                                 128)
#
#  upsamp_res_1/2 (Sequential)    (None, None, None,   131328      ['downsamp_res_1/4[0][0]']
#                                 64)
#
# ...
