# %%
# !pwd
# Out:
# /massimal/python/dataset_specific/20220630_Juvika

# %%
import sys
sys.path.append("/massimal/python/tools")
#sys.path.append("/tf/workspace/massimal/python/massimal/tools")

# %%
# Imports
import tensorflow as tf
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import skimage
# "Local import" from massimal repository (https://github.com/mh-skjelvareid/massimal)
import annotation, image_render, hyspec_io, misc, hyspec_stats, hyspec_cnn
import importlib
#importlib.reload(hyspec_stats)

import sklearn.preprocessing
import sklearn.decomposition
import math

# %%
sys.path
# Out:
# ['/massimal/python/dataset_specific/20220630_Juvika',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/massimal/python/tools']

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Parameters
TILE_SHAPE = (128,128)
TEST_FRAC = 0.3
# BATCH_SIZE = 16
# BATCH_SIZE = 32
BATCH_SIZE = 8

OUTPUT_CHANNELS = 7

# %%
# Paths
# base_dir = '/media/mha114/Massimal/Bodo_Juvika/Hyperspectral/20220624/'
base_dir = '/massimal/data/Bodo_Juvika/Hyperspectral/20220624/'

json_gray = base_dir + 'Area/M_Annotation/20220624_Juvika_AreaDetailed_v1/Annotations - grayscale/label_classes.json'
annotation_dir = base_dir + 'Area/M_Annotation/20220624_Juvika_AreaDetailed_v1/Annotations - grayscale'
hyspec_dir = base_dir + 'Area/2_R_rs'
dataset_filename = base_dir + 'Area/M_TensorFlow_Datasets/128-TilesWithWeights/128-TilesWithWeights'

# %%
# Load dataset
dataset = tf.data.Dataset.load(dataset_filename)

# %%
# Show some of the elements of the dataset
for image, mask, weights in dataset.take(1):    # Note: Must interate over dataset to "get" elements
    fig,ax = plt.subplots(1,3,figsize=(18,6))
    ax[0].imshow(image_render.percentile_stretch(np.array(image)[:,:,0:3]))
    ax[1].imshow(np.array(mask),cmap='gray')
    ax[2].imshow(np.array(weights),cmap='gray',vmin=0,vmax=20)
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
wgts = np.array(weights)
print(np.max(wgts))
print(np.min(wgts))
# Out:
# 4.3942475
# 0.1

# %%
print(len(dataset))
# Out:
# 257

# %%
# Split into training and validation datasets, create batches
n_val_tiles = int(TEST_FRAC*len(dataset))

dataset = dataset.shuffle(len(dataset))
val_dataset = dataset.take(n_val_tiles).batch(BATCH_SIZE)
train_dataset = dataset.skip(n_val_tiles).batch(BATCH_SIZE)

# %%
# Create the U-Net model
unet = hyspec_cnn.unet(input_channels=dataset.element_spec[0].shape[-1],
                       output_channels=OUTPUT_CHANNELS,
                       first_layer_channels=32,
                       depth = 5,
                       apply_batchnorm=True,
                       apply_dropout=True,
                       flip_aug=False,
                       trans_aug=False)
unet.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, None, None,  0           []
#                                  10)]
#
#  initial_convolution (Conv2D)   (None, None, None,   2912        ['input_image[0][0]']
#                                 32)
#
#  downsamp_res_1/2 (Sequential)  (None, None, None,   33024       ['initial_convolution[0][0]']
#                                 64)
#
#  downsamp_res_1/4 (Sequential)  (None, None, None,   131584      ['downsamp_res_1/2[0][0]']
#                                 128)
#
#  downsamp_res_1/8 (Sequential)  (None, None, None,   525312      ['downsamp_res_1/4[0][0]']
#                                 256)
#
#  downsamp_res_1/16 (Sequential)  (None, None, None,   2099200    ['downsamp_res_1/8[0][0]']
#                                 512)
#
#  downsamp_res_1/32 (Sequential)  (None, None, None,   8392704    ['downsamp_res_1/16[0][0]']
#                                 1024)
#
#  upsamp_res_1/16 (Sequential)   (None, None, None,   8390656     ['downsamp_res_1/32[0][0]']
#                                 512)
#
#  skipconnection_res_1/16 (Conca  (None, None, None,   0          ['upsamp_res_1/16[0][0]',
#  tenate)                        1024)                             'downsamp_res_1/16[0][0]']
#
#  upsamp_res_1/8 (Sequential)    (None, None, None,   8390656     ['skipconnection_res_1/16[0][0]']
#                                 512)
#
#  skipconnection_res_1/8 (Concat  (None, None, None,   0          ['upsamp_res_1/8[0][0]',
#  enate)                         768)                              'downsamp_res_1/8[0][0]']
#
#  upsamp_res_1/4 (Sequential)    (None, None, None,   3146752     ['skipconnection_res_1/8[0][0]']
#                                 256)
#
#  skipconnection_res_1/4 (Concat  (None, None, None,   0          ['upsamp_res_1/4[0][0]',
#  enate)                         384)                              'downsamp_res_1/4[0][0]']
#
#  upsamp_res_1/2 (Sequential)    (None, None, None,   786944      ['skipconnection_res_1/4[0][0]']
#                                 128)
#
#  skipconnection_res_1/2 (Concat  (None, None, None,   0          ['upsamp_res_1/2[0][0]',
#  enate)                         192)                              'downsamp_res_1/2[0][0]']
#
#  upsamp_res_1/1 (Sequential)    (None, None, None,   196864      ['skipconnection_res_1/2[0][0]']
#                                 64)
#
#  skipconnection_res_1/1 (Concat  (None, None, None,   0          ['upsamp_res_1/1[0][0]',
#  enate)                         96)                               'initial_convolution[0][0]']
#
#  classification (Conv2D)        (None, None, None,   6055        ['skipconnection_res_1/1[0][0]']
#                                 7)
#
# ==================================================================================================
# Total params: 32,102,663
# Trainable params: 32,095,751
# Non-trainable params: 6,912
# __________________________________________________________________________________________________

# %%
# Compile model. NOTE: Need smaller learning rate than standard RMSprop
# unet.compile(optimizer=tf.keras.optimizers.RMSprop(0.0001), 
#              loss="sparse_categorical_crossentropy",
#              weighted_metrics=[])

unet.compile(optimizer=tf.keras.optimizers.Adam(0.00002), 
             loss="sparse_categorical_crossentropy",
             weighted_metrics=[])

# %%
# Fit model to dataset
history = unet.fit(train_dataset,
                   epochs=100,
                   validation_data=val_dataset)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 17s 547ms/step - loss: 5.1547 - val_loss: 4.0018
# Epoch 2/100
# 23/23 [==============================] - 12s 531ms/step - loss: 4.2196 - val_loss: 3.8161
# Epoch 3/100
# 23/23 [==============================] - 12s 534ms/step - loss: 3.9377 - val_loss: 3.6073
# Epoch 4/100
# 23/23 [==============================] - 12s 530ms/step - loss: 4.0477 - val_loss: 4.2302
# Epoch 5/100
# 23/23 [==============================] - 12s 531ms/step - loss: 3.8141 - val_loss: 3.8285
# Epoch 6/100
# 23/23 [==============================] - 12s 531ms/step - loss: 3.4957 - val_loss: 4.2916
# Epoch 7/100
# 23/23 [==============================] - 12s 534ms/step - loss: 3.3323 - val_loss: 4.0824
# Epoch 8/100
# 23/23 [==============================] - 12s 535ms/step - loss: 3.3197 - val_loss: 3.8238
# Epoch 9/100
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# Reduce learning rate
unet.optimizer.learning_rate.assign(0.000002)
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=float32, numpy=2e-06>

# %%
unet.optimizer.learning_rate
# Out:
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=2e-06>

# %%
# Fit model to dataset (resume)
history = unet.fit(train_dataset,
                   epochs=50,
                   validation_data=val_dataset)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 13s 542ms/step - loss: 0.9577 - val_loss: 0.5049
# Epoch 2/50
# 23/23 [==============================] - 13s 538ms/step - loss: 0.8214 - val_loss: 0.5722
# Epoch 3/50
# 23/23 [==============================] - 12s 535ms/step - loss: 1.0214 - val_loss: 0.4530
# Epoch 4/50
# 23/23 [==============================] - 12s 534ms/step - loss: 0.9078 - val_loss: 0.4948
# Epoch 5/50
# 23/23 [==============================] - 12s 539ms/step - loss: 1.0056 - val_loss: 0.4902
# Epoch 6/50
# 23/23 [==============================] - 12s 537ms/step - loss: 0.8042 - val_loss: 0.4763
# Epoch 7/50
# 23/23 [==============================] - 12s 537ms/step - loss: 0.9099 - val_loss: 0.4665
# Epoch 8/50
# 23/23 [==============================] - 12s 537ms/step - loss: 0.9688 - val_loss: 0.5446
# Epoch 9/50
# 23/23 [==============================] - 12s 530ms/step - loss: 0.8499 - val_loss: 0.5472
# Epoch 10/50
# 23/23 [==============================] - 12s 531ms/step - loss: 0.9236 - val_loss: 0.5462
# Epoch 11/50
# 23/23 [==============================] - 13s 544ms/step - loss: 0.9844 - val_loss: 0.5005
# Epoch 12/50
# 23/23 [==============================] - 12s 534ms/step - loss: 0.9290 - val_loss: 0.6082
# Epoch 13/50
# 23/23 [==============================] - 12s 534ms/step - loss: 0.9298 - val_loss: 0.5171
# Epoch 14/50
# 23/23 [==============================] - 13s 536ms/step - loss: 0.7965 - val_loss: 0.5751
# Epoch 15/50
# 23/23 [==============================] - 12s 537ms/step - loss: 0.8600 - val_loss: 0.4963
# Epoch 16/50
# 23/23 [==============================] - 12s 539ms/step - loss: 0.8800 - val_loss: 0.4958
# Epoch 17/50
# 23/23 [==============================] - 13s 538ms/step - loss: 0.8701 - val_loss: 0.5009
# Epoch 18/50
# 23/23 [==============================] - 14s 548ms/step - loss: 0.8680 - val_loss: 0.5167
# Epoch 19/50
# 23/23 [==============================] - 13s 537ms/step - loss: 0.8032 - val_loss: 0.5948
# Epoch 20/50
# 23/23 [==============================] - 13s 552ms/step - loss: 1.0971 - val_loss: 0.5227
# Epoch 21/50
# 23/23 [==============================] - 13s 543ms/step - loss: 1.1683 - val_loss: 0.5344
# Epoch 22/50
# 23/23 [==============================] - 13s 539ms/step - loss: 1.0410 - val_loss: 0.5857
# Epoch 23/50
# 23/23 [==============================] - 13s 550ms/step - loss: 0.8519 - val_loss: 0.6290
# Epoch 24/50
# 23/23 [==============================] - 13s 577ms/step - loss: 0.8706 - val_loss: 0.4574
# Epoch 25/50
# 23/23 [==============================] - 12s 532ms/step - loss: 1.0281 - val_loss: 0.5703
# Epoch 26/50
# 23/23 [==============================] - 13s 553ms/step - loss: 1.1791 - val_loss: 0.5707
# Epoch 27/50
# 23/23 [==============================] - 12s 529ms/step - loss: 0.9035 - val_loss: 0.5603
# Epoch 28/50
# 23/23 [==============================] - 12s 531ms/step - loss: 0.8018 - val_loss: 0.5310
# Epoch 29/50
# 23/23 [==============================] - 12s 531ms/step - loss: 0.8470 - val_loss: 0.4922
# Epoch 30/50
# 23/23 [==============================] - 13s 544ms/step - loss: 0.8965 - val_loss: 0.5029
# Epoch 31/50
# 23/23 [==============================] - 13s 538ms/step - loss: 0.8606 - val_loss: 0.6082
# Epoch 32/50
# 23/23 [==============================] - 12s 534ms/step - loss: 0.8920 - val_loss: 0.5146
# Epoch 33/50
# 23/23 [==============================] - 12s 530ms/step - loss: 0.7816 - val_loss: 0.5124
# Epoch 34/50
# 23/23 [==============================] - 12s 535ms/step - loss: 0.8078 - val_loss: 0.5096
# Epoch 35/50
# 23/23 [==============================] - 12s 530ms/step - loss: 0.8893 - val_loss: 0.5501
# Epoch 36/50
# 23/23 [==============================] - 13s 536ms/step - loss: 0.9907 - val_loss: 0.5640
# Epoch 37/50
# 23/23 [==============================] - 13s 540ms/step - loss: 0.8666 - val_loss: 0.5516
# Epoch 38/50
# 23/23 [==============================] - 13s 543ms/step - loss: 0.9735 - val_loss: 0.5206
# Epoch 39/50
# 23/23 [==============================] - 12s 533ms/step - loss: 0.7819 - val_loss: 0.5244
# Epoch 40/50
# 23/23 [==============================] - 12s 535ms/step - loss: 0.8960 - val_loss: 0.5614
# Epoch 41/50
# 23/23 [==============================] - 13s 541ms/step - loss: 0.9070 - val_loss: 0.4609
# Epoch 42/50
# 23/23 [==============================] - 12s 534ms/step - loss: 0.9255 - val_loss: 0.5016
# Epoch 43/50
# 23/23 [==============================] - 12s 534ms/step - loss: 0.7769 - val_loss: 0.6114
# Epoch 44/50
# 23/23 [==============================] - 12s 534ms/step - loss: 0.9100 - val_loss: 0.4924
# Epoch 45/50
# 23/23 [==============================] - 12s 537ms/step - loss: 0.8183 - val_loss: 0.4662
# Epoch 46/50
# 23/23 [==============================] - 13s 550ms/step - loss: 0.8026 - val_loss: 0.5617
# Epoch 47/50
# 23/23 [==============================] - 13s 539ms/step - loss: 0.8178 - val_loss: 0.6563
# Epoch 48/50
# 23/23 [==============================] - 12s 532ms/step - loss: 1.0271 - val_loss: 0.5224
# Epoch 49/50
# 23/23 [==============================] - 13s 554ms/step - loss: 0.9868 - val_loss: 0.5827
# Epoch 50/50
# 23/23 [==============================] - 13s 542ms/step - loss: 0.9623 - val_loss: 0.5806

# %%
unet.optimizer.get_config()
# Out:
# {'name': 'Adam',
#  'weight_decay': None,
#  'clipnorm': None,
#  'global_clipnorm': None,
#  'clipvalue': None,
#  'use_ema': False,
#  'ema_momentum': 0.99,
#  'ema_overwrite_frequency': None,
#  'jit_compile': True,
#  'is_legacy_optimizer': False,
#  'learning_rate': 2e-06,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
epochs = range(1, len(history.history["loss"]) + 1)
loss = history.history["loss"]
val_loss = history.history["val_loss"]
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()
