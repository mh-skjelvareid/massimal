# %%
import tensorflow as tf
import numpy as np

import hyspec_cnn

# %%
# Test model function
input_channels = 10
output_channels = 4
first_layer_channels = 32
depth = 3

model = hyspec_cnn.unet(input_channels,output_channels, first_layer_channels,depth)
# Out:
# 2023-02-07 14:58:16.807868: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2023-02-07 14:58:16.807892: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: mha114-ThinkPad-P52
# 2023-02-07 14:58:16.807898: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: mha114-ThinkPad-P52
# 2023-02-07 14:58:16.807955: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.161.3
# 2023-02-07 14:58:16.807973: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.161.3
# 2023-02-07 14:58:16.807977: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.161.3
# ...

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_image (InputLayer)       [(None, None, None,  0           []
#                                  10)]
#
#  augmentation (Sequential)      (None, None, None,   0           ['input_image[0][0]']
#                                 10)
#
#  initial_convolution (Conv2D)   (None, None, None,   2912        ['augmentation[0][0]']
#                                 32)
#
#  downsamp_res_1/2 (Sequential)  (None, None, None,   33024       ['initial_convolution[0][0]']
#                                 64)
#
#  downsamp_res_1/4 (Sequential)  (None, None, None,   131584      ['downsamp_res_1/2[0][0]']
#                                 128)
#
#  downsamp_res_1/8 (Sequential)  (None, None, None,   525312      ['downsamp_res_1/4[0][0]']
#                                 256)
#
# ...

# %%
tf.keras.utils.plot_model(model,show_shapes=True)
