# %%
import video_transect
from pathlib import Path
import exiftool
import datetime
import pandas as pd
import shutil
import tqdm

# %%
# Paths
im_dir = Path('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images')
csv_file = Path('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/GnssData/20230620_144519_GnssTimePosHeadCourSpeed.csv')
test_gpkg_output = Path('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/ImagesGeopackage/20230620_Smola_Skalmen_OtterImages.gpkg')

# %%
# Parameters
sample_distance = 1.0 # Units defined by CRS, default is UTM with unit meters

# %%
# Get list of **all** image files
im_files = sorted(list(im_dir.rglob('*.JPG')))

for im_file in im_files[0:5]:
    print(im_file)
print('...')
for im_file in im_files[-5:]:
    print(im_file)

print(f'{len(im_files)} image files found')
# Out:
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/100GOPRO/G0011753.JPG
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/100GOPRO/G0011754.JPG
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/100GOPRO/G0011755.JPG
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/100GOPRO/G0011756.JPG
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/100GOPRO/G0011757.JPG
# ...
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro2/125GOPRO/G0054533.JPG
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro2/125GOPRO/G0054534.JPG
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro2/125GOPRO/G0054535.JPG
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro2/125GOPRO/G0054536.JPG
# /media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro2/125GOPRO/G0054537.JPG
# 30466 image files found

# %%
def get_image_timestamps(image_paths):
    """ Get subsecond-accuracy timestamps for every image file in a list
    
    # Input parameters:
    image_paths:
        List of image paths, used by exiftool method ExifToolHelper.get_metadata()
    
    # Returns:
    image_paths_and_timestamps:
        List of tuples containing (image_path, image_timestamp_string)
    """
    with exiftool.ExifToolHelper() as et:
        metadata = et.get_metadata(image_paths)
    image_paths_and_timestamps = [(im_path,md['Composite:SubSecCreateDate']) 
                                  for (im_path,md) in zip(image_paths,metadata) 
                                  if 'Composite:SubSecCreateDate' in md]
    return image_paths_and_timestamps

# %%
# im_files_test = im_files[::100]  # Every 100'th image, for testing
im_files_test = im_files[10000:10100]  # 100 images from middle, for testing
print(len(im_files_test))
# Out:
# 100

# %%
# Get EXIF data for images. If all images, this takes approx. 8 minutes
image_paths_and_timestamps = get_image_timestamps(im_files_test)
for im_ts in image_paths_and_timestamps:
    print(im_ts)
print(f'Got {len(image_paths_and_timestamps)} valid timestamps.')
# Out:
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021754.JPG'), '2023:06:20 17:46:36.4450')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021755.JPG'), '2023:06:20 17:46:36.9460')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021756.JPG'), '2023:06:20 17:46:37.4460')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021757.JPG'), '2023:06:20 17:46:37.9470')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021758.JPG'), '2023:06:20 17:46:38.4470')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021759.JPG'), '2023:06:20 17:46:38.9480')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021760.JPG'), '2023:06:20 17:46:39.4480')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021761.JPG'), '2023:06:20 17:46:39.9490')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021762.JPG'), '2023:06:20 17:46:40.4490')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021763.JPG'), '2023:06:20 17:46:40.9500')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021764.JPG'), '2023:06:20 17:46:41.4500')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021765.JPG'), '2023:06:20 17:46:41.9510')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021766.JPG'), '2023:06:20 17:46:42.4510')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021767.JPG'), '2023:06:20 17:46:42.9520')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021768.JPG'), '2023:06:20 17:46:43.4520')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021769.JPG'), '2023:06:20 17:46:43.9530')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021770.JPG'), '2023:06:20 17:46:44.4530')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021771.JPG'), '2023:06:20 17:46:44.9540')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021772.JPG'), '2023:06:20 17:46:45.4540')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021773.JPG'), '2023:06:20 17:46:45.9550')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021774.JPG'), '2023:06:20 17:46:46.4550')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021775.JPG'), '2023:06:20 17:46:46.9560')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021776.JPG'), '2023:06:20 17:46:47.4560')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021777.JPG'), '2023:06:20 17:46:47.9570')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021778.JPG'), '2023:06:20 17:46:48.4570')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021779.JPG'), '2023:06:20 17:46:48.9580')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021780.JPG'), '2023:06:20 17:46:49.4580')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021781.JPG'), '2023:06:20 17:46:49.9590')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021782.JPG'), '2023:06:20 17:46:50.4590')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021783.JPG'), '2023:06:20 17:46:50.9600')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021784.JPG'), '2023:06:20 17:46:51.4600')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021785.JPG'), '2023:06:20 17:46:51.9610')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021786.JPG'), '2023:06:20 17:46:52.4610')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021787.JPG'), '2023:06:20 17:46:52.9620')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021788.JPG'), '2023:06:20 17:46:53.4620')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021789.JPG'), '2023:06:20 17:46:53.9630')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021790.JPG'), '2023:06:20 17:46:54.4630')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021791.JPG'), '2023:06:20 17:46:54.9640')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021792.JPG'), '2023:06:20 17:46:55.4640')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021793.JPG'), '2023:06:20 17:46:55.9650')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021794.JPG'), '2023:06:20 17:46:56.4650')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021795.JPG'), '2023:06:20 17:46:56.9660')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021796.JPG'), '2023:06:20 17:46:57.4660')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021797.JPG'), '2023:06:20 17:46:57.9670')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021798.JPG'), '2023:06:20 17:46:58.4670')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021799.JPG'), '2023:06:20 17:46:58.9680')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021800.JPG'), '2023:06:20 17:46:59.4680')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021801.JPG'), '2023:06:20 17:46:59.9690')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021802.JPG'), '2023:06:20 17:47:00.4690')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021803.JPG'), '2023:06:20 17:47:00.9700')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021804.JPG'), '2023:06:20 17:47:01.4700')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021805.JPG'), '2023:06:20 17:47:01.9710')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021806.JPG'), '2023:06:20 17:47:02.4710')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021807.JPG'), '2023:06:20 17:47:02.9720')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021808.JPG'), '2023:06:20 17:47:03.4720')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021809.JPG'), '2023:06:20 17:47:03.9730')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021810.JPG'), '2023:06:20 17:47:04.4730')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021811.JPG'), '2023:06:20 17:47:04.9740')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021812.JPG'), '2023:06:20 17:47:05.4740')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021813.JPG'), '2023:06:20 17:47:05.9750')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021814.JPG'), '2023:06:20 17:47:06.4750')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021815.JPG'), '2023:06:20 17:47:06.9760')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021816.JPG'), '2023:06:20 17:47:07.4760')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021817.JPG'), '2023:06:20 17:47:07.9770')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021818.JPG'), '2023:06:20 17:47:08.4770')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021819.JPG'), '2023:06:20 17:47:08.9780')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021820.JPG'), '2023:06:20 17:47:09.4780')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021821.JPG'), '2023:06:20 17:47:09.9790')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021822.JPG'), '2023:06:20 17:47:10.4790')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021823.JPG'), '2023:06:20 17:47:10.9800')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021824.JPG'), '2023:06:20 17:47:11.4800')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021825.JPG'), '2023:06:20 17:47:11.9810')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021826.JPG'), '2023:06:20 17:47:12.4810')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021827.JPG'), '2023:06:20 17:47:12.9820')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021828.JPG'), '2023:06:20 17:47:13.4820')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021829.JPG'), '2023:06:20 17:47:13.9830')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021830.JPG'), '2023:06:20 17:47:14.4830')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021831.JPG'), '2023:06:20 17:47:14.9840')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021832.JPG'), '2023:06:20 17:47:15.4840')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021833.JPG'), '2023:06:20 17:47:15.9850')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021834.JPG'), '2023:06:20 17:47:16.4850')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021835.JPG'), '2023:06:20 17:47:16.9860')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021836.JPG'), '2023:06:20 17:47:17.4860')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021837.JPG'), '2023:06:20 17:47:17.9870')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021838.JPG'), '2023:06:20 17:47:18.4870')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021839.JPG'), '2023:06:20 17:47:18.9880')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021840.JPG'), '2023:06:20 17:47:19.4880')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021841.JPG'), '2023:06:20 17:47:19.9890')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021842.JPG'), '2023:06:20 17:47:20.4890')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021843.JPG'), '2023:06:20 17:47:20.9900')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021844.JPG'), '2023:06:20 17:47:21.4900')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021845.JPG'), '2023:06:20 17:47:21.9910')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021846.JPG'), '2023:06:20 17:47:22.4910')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021847.JPG'), '2023:06:20 17:47:22.9920')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021848.JPG'), '2023:06:20 17:47:23.4920')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021849.JPG'), '2023:06:20 17:47:23.9930')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021850.JPG'), '2023:06:20 17:47:24.4930')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021851.JPG'), '2023:06:20 17:47:24.9940')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021852.JPG'), '2023:06:20 17:47:25.4940')
# (PosixPath('/media/mha114/Massimal2/Massimal/Smola_Skalmen/OtterTransects/20230620/Images/GoPro1/110GOPRO/G0021853.JPG'), '2023:06:20 17:47:25.9950')
# Got 100 valid timestamps.

# %%
# Get Otter positions, show geodataframe
otter_gdf = video_transect.otter_csv_to_geodataframe(csv_file)
otter_gdf
# Out:
#                                    Time        Lat       Lng  \
# 0      2023-06-20 14:45:19.418000+00:00  63.464339  7.771215
# 1      2023-06-20 14:45:19.513000+00:00  63.464339  7.771212
# 2      2023-06-20 14:45:19.609000+00:00  63.464339  7.771209
# 3      2023-06-20 14:45:19.705000+00:00  63.464339  7.771206
# 4      2023-06-20 14:45:19.817000+00:00  63.464339  7.771203
# ...                                 ...        ...       ...
# 145175 2023-06-20 18:47:17.026000+00:00  63.463280  7.775832
# 145176 2023-06-20 18:47:17.122000+00:00  63.463280  7.775832
# 145177 2023-06-20 18:47:17.234000+00:00  63.463280  7.775832
# 145178 2023-06-20 18:47:17.330000+00:00  63.463280  7.775832
# 145179 2023-06-20 18:47:17.426000+00:00  63.463280  7.775833
#
#                         geometry
# 0       POINT (7.77122 63.46434)
# 1       POINT (7.77121 63.46434)
# 2       POINT (7.77121 63.46434)
# 3       POINT (7.77121 63.46434)
# 4       POINT (7.77120 63.46434)
# ...                          ...
# 145175  POINT (7.77583 63.46328)
# 145176  POINT (7.77583 63.46328)
# 145177  POINT (7.77583 63.46328)
# 145178  POINT (7.77583 63.46328)
# 145179  POINT (7.77583 63.46328)
#
# [145180 rows x 4 columns]

# %% [markdown]
# # Matching timestamps
# **Notes below are included because they led to the discovery of duplicated data**
#
# GoPro images start at approx. 16:23 and end at approx. 21:17 (approx 5 hours)
# Otter timestamps start at 14:45 and end at 18:47 (approx. 4 hours!)
#
# Otter times are UTC, meaning that the times (in summer) are 2 hours ahead of local time.
#
# First GoPro image from camera 1 taken 16:23:11
# First GoPro image from camera 2 taken 18:56:00, on June 19! From day before...? Or incorrect date setting?
#
# Last GoPro image from camera 1 taken 18:41:00 on June 20
# Last GoPro image from camera 2 taken 21:18:28 on June 20
#
# Image G0020571.JPG in folder 20230620/Images/GoPro2/110GOPRO is the last image taken on June 19.
#
# File naming does not follow folder naming, but is formatted as G00Xdddd, where X indicates the "sequence number".
#
# AHA! The image sequences 1 and 2 from camera 2 are _duplicated_. They are included in the datasets both from Måholmen (June 19) and Skalmen (June 20.). Image sequence 3 is just a test sequence taken indoors.
#
# Fix: Remove duplicated images from camera 2 from Skalmen dataset.

# %% [markdown]
# # Matching timestamps 2
# Otter timestamps start at 14:45 and end at 18:47 (approx. 4 hours!)
#
# Otter times are UTC, meaning that the times (in summer) are 2 hours ahead of local time.
#
# First GoPro image from camera 1 taken 16:23:11
# Last GoPro image from camera 1 taken 18:41:00 (approx 2 hours and 20 minutes)
# All images appear to be taken in one continuous take.
#
# First GoPro image from camera 2 taken 19:22:10
# Last GoPro image from camera 2 taken 21:18:28
# All these images also appear to be taken in one continuous take
#
# The interval 18:41 - 19:22 makes sense - it probably took 40 minutes to change cameras. This again indicates that from beginning to end, imaging took approx. 5 hours (including camera change). So were the cameras started before the Otter GPS logging started, or stopped long after the Otter stopped?
#
# For camera 1, the first indication of movement is around image G0013150.JPG, taken at 16:34:50.
#
# If the camera and Otter are offset by exactly 2 hours, then the first image of the Otter position log is around G0014406.JPG. At this point, the images show the Otter being above kelp (hard to interpret movement), but soon after, the Otter appears to head out to deeper waters. Not really any obvious break here...
#
# Plotting Otter path in QGIS: First point seems to be while moving westwards towards start of grid. Not an obvious starting position, maybe Håvard just started logging there.
#
# If Otter log stops at 18:47 UTC (22:47 local time), it means that approx. the last half hour of images from GoPro 2 doesn't have positions.

# %%
def get_otter_image_positions(otter_gdf,image_paths_and_timestamps,
                              dt_format = r'%Y:%m:%d %H:%M:%S.%f',
                              time_tolerance = datetime.timedelta(seconds=1),
                              image_time_offset_from_utc = datetime.timedelta(hours=2)):
    """ Search Otter geodataframe for positions closest to image (in time)
    
    # Input arguments:
    otter_gdf:      
        GDF created from Otter CSV (see otter_csv_to_geodataframe())
        Only column "Time" (containing UTC datetime objects) is used
    image_paths_and_timestamps:
        List of tuples containing (image_path, image_timestamp_string)
    time_tolerance:
        datetime.timedelta, default 1 second, indicating maximum time offset
        when searching for matching times between images and positions
    image_time_offset_from_utc:
        datetime.timedelta, default 2 hours, indicating time offset between
        utc and image timestamps (typically local time).
    
    # Returns
    image_gdf:
        Geodataframe with positions (taken form Otter) and corresponding
        image file paths. 
    
    """
    
    # Extract timestamps and convert to datetime objects
    image_datetimes = [pd.to_datetime(image_datetime_str,format=dt_format,utc=True) 
                       - image_time_offset_from_utc
                       for (_,image_datetime_str) in image_paths_and_timestamps]

    # Find indices for Otter timestamps that are closest to image timestamps
    closest_time_index = pd.Index(otter_gdf['Time']).get_indexer(image_datetimes,method='nearest',
                                                                 tolerance=time_tolerance)
    
    # Remove images that don't have any matches within the time tolerance
    image_paths = [image_path for ((image_path,_),im_index) in 
                   zip(image_paths_and_timestamps,closest_time_index)
                   if im_index >= 0] # Images without match get index -1
    closest_time_index = closest_time_index[closest_time_index>=0]

    # Create copy of Otter gdf which only contains rows corresponding to images
    image_gdf = otter_gdf.iloc[closest_time_index]
    
    # Insert additional column for image path
    image_gdf.insert(image_gdf.shape[1]-1,'ImageFile','')
    image_gdf.iloc[:,image_gdf.columns.get_loc('ImageFile')] = image_paths
    return image_gdf

# %%
image_gdf = get_otter_image_positions(otter_gdf,image_paths_and_timestamps)
image_gdf
# Out:
#                                   Time        Lat       Lng  \
# 36769 2023-06-20 15:46:36.431000+00:00  63.466281  7.765075
# 36774 2023-06-20 15:46:36.927000+00:00  63.466280  7.765088
# 36779 2023-06-20 15:46:37.423000+00:00  63.466279  7.765101
# 36784 2023-06-20 15:46:37.919000+00:00  63.466278  7.765113
# 36789 2023-06-20 15:46:38.431000+00:00  63.466277  7.765126
# ...                                ...        ...       ...
# 37245 2023-06-20 15:47:24.028000+00:00  63.466275  7.766308
# 37250 2023-06-20 15:47:24.524000+00:00  63.466275  7.766320
# 37255 2023-06-20 15:47:25.020000+00:00  63.466275  7.766333
# 37260 2023-06-20 15:47:25.532000+00:00  63.466274  7.766346
# 37265 2023-06-20 15:47:26.028000+00:00  63.466274  7.766360
#
#                                                ImageFile  \
# 36769  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36774  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36779  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36784  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36789  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# ...                                                  ...
# 37245  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37250  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37255  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37260  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37265  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
#
#                        geometry
# 36769  POINT (7.76508 63.46628)
# 36774  POINT (7.76509 63.46628)
# 36779  POINT (7.76510 63.46628)
# 36784  POINT (7.76511 63.46628)
# 36789  POINT (7.76513 63.46628)
# ...                         ...
# 37245  POINT (7.76631 63.46627)
# 37250  POINT (7.76632 63.46627)
# 37255  POINT (7.76633 63.46627)
# 37260  POINT (7.76635 63.46627)
# 37265  POINT (7.76636 63.46627)
#
# [100 rows x 5 columns]

# %%
image_gdf_filt = video_transect.filter_gdf_on_distance(image_gdf,sample_distance)
image_gdf_filt
# Out:
#                                   Time        Lat       Lng  \
# 36769 2023-06-20 15:46:36.431000+00:00  63.466281  7.765075
# 36779 2023-06-20 15:46:37.423000+00:00  63.466279  7.765101
# 36789 2023-06-20 15:46:38.431000+00:00  63.466277  7.765126
# 36799 2023-06-20 15:46:39.423000+00:00  63.466276  7.765154
# 36809 2023-06-20 15:46:40.431000+00:00  63.466275  7.765180
# 36819 2023-06-20 15:46:41.423000+00:00  63.466274  7.765204
# 36829 2023-06-20 15:46:42.431000+00:00  63.466273  7.765231
# 36839 2023-06-20 15:46:43.423000+00:00  63.466272  7.765259
# 36849 2023-06-20 15:46:44.431000+00:00  63.466271  7.765285
# 36859 2023-06-20 15:46:45.423000+00:00  63.466271  7.765310
# 36869 2023-06-20 15:46:46.431000+00:00  63.466271  7.765337
# 36879 2023-06-20 15:46:47.423000+00:00  63.466270  7.765364
# 36889 2023-06-20 15:46:48.431000+00:00  63.466271  7.765390
# 36899 2023-06-20 15:46:49.423000+00:00  63.466271  7.765416
# 36909 2023-06-20 15:46:50.430000+00:00  63.466272  7.765443
# 36919 2023-06-20 15:46:51.422000+00:00  63.466272  7.765468
# 36929 2023-06-20 15:46:52.430000+00:00  63.466273  7.765495
# 36939 2023-06-20 15:46:53.422000+00:00  63.466273  7.765522
# 36949 2023-06-20 15:46:54.430000+00:00  63.466274  7.765548
# 36959 2023-06-20 15:46:55.422000+00:00  63.466274  7.765573
# 36969 2023-06-20 15:46:56.430000+00:00  63.466275  7.765601
# 36979 2023-06-20 15:46:57.422000+00:00  63.466276  7.765627
# 36989 2023-06-20 15:46:58.430000+00:00  63.466276  7.765652
# 36999 2023-06-20 15:46:59.422000+00:00  63.466276  7.765678
# 37009 2023-06-20 15:47:00.430000+00:00  63.466277  7.765705
# 37020 2023-06-20 15:47:01.518000+00:00  63.466277  7.765733
# 37029 2023-06-20 15:47:02.430000+00:00  63.466277  7.765757
# 37040 2023-06-20 15:47:03.517000+00:00  63.466277  7.765787
# 37049 2023-06-20 15:47:04.429000+00:00  63.466278  7.765809
# 37060 2023-06-20 15:47:05.517000+00:00  63.466278  7.765836
# 37069 2023-06-20 15:47:06.429000+00:00  63.466278  7.765859
# 37080 2023-06-20 15:47:07.517000+00:00  63.466277  7.765888
# 37090 2023-06-20 15:47:08.525000+00:00  63.466277  7.765913
# 37100 2023-06-20 15:47:09.517000+00:00  63.466277  7.765939
# 37110 2023-06-20 15:47:10.525000+00:00  63.466277  7.765964
# 37120 2023-06-20 15:47:11.533000+00:00  63.466277  7.765989
# 37130 2023-06-20 15:47:12.525000+00:00  63.466276  7.766016
# 37140 2023-06-20 15:47:13.533000+00:00  63.466276  7.766043
# 37150 2023-06-20 15:47:14.525000+00:00  63.466276  7.766067
# 37160 2023-06-20 15:47:15.533000+00:00  63.466276  7.766092
# 37170 2023-06-20 15:47:16.525000+00:00  63.466276  7.766118
# 37180 2023-06-20 15:47:17.533000+00:00  63.466275  7.766142
# 37190 2023-06-20 15:47:18.525000+00:00  63.466275  7.766168
# 37200 2023-06-20 15:47:19.532000+00:00  63.466275  7.766195
# 37210 2023-06-20 15:47:20.524000+00:00  63.466275  7.766220
# 37220 2023-06-20 15:47:21.532000+00:00  63.466275  7.766244
# 37230 2023-06-20 15:47:22.524000+00:00  63.466275  7.766270
# 37240 2023-06-20 15:47:23.532000+00:00  63.466275  7.766295
# 37250 2023-06-20 15:47:24.524000+00:00  63.466275  7.766320
# 37260 2023-06-20 15:47:25.532000+00:00  63.466274  7.766346
#
#                                                ImageFile  \
# 36769  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36779  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36789  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36799  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36809  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36819  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36829  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36839  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36849  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36859  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36869  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36879  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36889  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36899  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36909  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36919  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36929  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36939  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36949  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36959  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36969  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36979  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36989  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 36999  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37009  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37020  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37029  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37040  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37049  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37060  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37069  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37080  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37090  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37100  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37110  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37120  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37130  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37140  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37150  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37160  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37170  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37180  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37190  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37200  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37210  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37220  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37230  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37240  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37250  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
# 37260  /media/mha114/Massimal2/Massimal/Smola_Skalmen...
#
#                        geometry
# 36769  POINT (7.76508 63.46628)
# 36779  POINT (7.76510 63.46628)
# 36789  POINT (7.76513 63.46628)
# 36799  POINT (7.76515 63.46628)
# 36809  POINT (7.76518 63.46627)
# 36819  POINT (7.76520 63.46627)
# 36829  POINT (7.76523 63.46627)
# 36839  POINT (7.76526 63.46627)
# 36849  POINT (7.76528 63.46627)
# 36859  POINT (7.76531 63.46627)
# 36869  POINT (7.76534 63.46627)
# 36879  POINT (7.76536 63.46627)
# 36889  POINT (7.76539 63.46627)
# 36899  POINT (7.76542 63.46627)
# 36909  POINT (7.76544 63.46627)
# 36919  POINT (7.76547 63.46627)
# 36929  POINT (7.76549 63.46627)
# 36939  POINT (7.76552 63.46627)
# 36949  POINT (7.76555 63.46627)
# 36959  POINT (7.76557 63.46627)
# 36969  POINT (7.76560 63.46628)
# 36979  POINT (7.76563 63.46628)
# 36989  POINT (7.76565 63.46628)
# 36999  POINT (7.76568 63.46628)
# 37009  POINT (7.76571 63.46628)
# 37020  POINT (7.76573 63.46628)
# 37029  POINT (7.76576 63.46628)
# 37040  POINT (7.76579 63.46628)
# 37049  POINT (7.76581 63.46628)
# 37060  POINT (7.76584 63.46628)
# 37069  POINT (7.76586 63.46628)
# 37080  POINT (7.76589 63.46628)
# 37090  POINT (7.76591 63.46628)
# 37100  POINT (7.76594 63.46628)
# 37110  POINT (7.76596 63.46628)
# 37120  POINT (7.76599 63.46628)
# 37130  POINT (7.76602 63.46628)
# 37140  POINT (7.76604 63.46628)
# 37150  POINT (7.76607 63.46628)
# 37160  POINT (7.76609 63.46628)
# 37170  POINT (7.76612 63.46628)
# 37180  POINT (7.76614 63.46628)
# 37190  POINT (7.76617 63.46628)
# 37200  POINT (7.76620 63.46628)
# 37210  POINT (7.76622 63.46627)
# 37220  POINT (7.76624 63.46627)
# 37230  POINT (7.76627 63.46627)
# 37240  POINT (7.76630 63.46627)
# 37250  POINT (7.76632 63.46627)
# 37260  POINT (7.76635 63.46627)

# %%
gdf = image_gdf_filt.copy()

# %%
# Get all image paths
im_paths = gdf.ImageFile
im_times = gdf.Time
image_filename_base = 'Smola_Skalmen_'
new_image_filenames = []
for i,(im_path,im_time) in enumerate(zip(im_paths,im_times)):
    new_image_filename = image_filename_base
    new_image_filename += f'{i:08d}_'
    new_image_filename += im_time.strftime("%Y%m%dT%H%M%SZ_")
    new_image_filename += im_path.name
    new_image_filenames.append(new_image_filename)

print(new_image_filenames)
# Out:
# ['Smola_Skalmen_00000000_20230620T154636Z_G0021754.JPG', 'Smola_Skalmen_00000001_20230620T154637Z_G0021756.JPG', 'Smola_Skalmen_00000002_20230620T154638Z_G0021758.JPG', 'Smola_Skalmen_00000003_20230620T154639Z_G0021760.JPG', 'Smola_Skalmen_00000004_20230620T154640Z_G0021762.JPG', 'Smola_Skalmen_00000005_20230620T154641Z_G0021764.JPG', 'Smola_Skalmen_00000006_20230620T154642Z_G0021766.JPG', 'Smola_Skalmen_00000007_20230620T154643Z_G0021768.JPG', 'Smola_Skalmen_00000008_20230620T154644Z_G0021770.JPG', 'Smola_Skalmen_00000009_20230620T154645Z_G0021772.JPG', 'Smola_Skalmen_00000010_20230620T154646Z_G0021774.JPG', 'Smola_Skalmen_00000011_20230620T154647Z_G0021776.JPG', 'Smola_Skalmen_00000012_20230620T154648Z_G0021778.JPG', 'Smola_Skalmen_00000013_20230620T154649Z_G0021780.JPG', 'Smola_Skalmen_00000014_20230620T154650Z_G0021782.JPG', 'Smola_Skalmen_00000015_20230620T154651Z_G0021784.JPG', 'Smola_Skalmen_00000016_20230620T154652Z_G0021786.JPG', 'Smola_Skalmen_00000017_20230620T154653Z_G0021788.JPG', 'Smola_Skalmen_00000018_20230620T154654Z_G0021790.JPG', 'Smola_Skalmen_00000019_20230620T154655Z_G0021792.JPG', 'Smola_Skalmen_00000020_20230620T154656Z_G0021794.JPG', 'Smola_Skalmen_00000021_20230620T154657Z_G0021796.JPG', 'Smola_Skalmen_00000022_20230620T154658Z_G0021798.JPG', 'Smola_Skalmen_00000023_20230620T154659Z_G0021800.JPG', 'Smola_Skalmen_00000024_20230620T154700Z_G0021802.JPG', 'Smola_Skalmen_00000025_20230620T154701Z_G0021804.JPG', 'Smola_Skalmen_00000026_20230620T154702Z_G0021806.JPG', 'Smola_Skalmen_00000027_20230620T154703Z_G0021808.JPG', 'Smola_Skalmen_00000028_20230620T154704Z_G0021810.JPG', 'Smola_Skalmen_00000029_20230620T154705Z_G0021812.JPG', 'Smola_Skalmen_00000030_20230620T154706Z_G0021814.JPG', 'Smola_Skalmen_00000031_20230620T154707Z_G0021816.JPG', 'Smola_Skalmen_00000032_20230620T154708Z_G0021818.JPG', 'Smola_Skalmen_00000033_20230620T154709Z_G0021820.JPG', 'Smola_Skalmen_00000034_20230620T154710Z_G0021822.JPG', 'Smola_Skalmen_00000035_20230620T154711Z_G0021824.JPG', 'Smola_Skalmen_00000036_20230620T154712Z_G0021826.JPG', 'Smola_Skalmen_00000037_20230620T154713Z_G0021828.JPG', 'Smola_Skalmen_00000038_20230620T154714Z_G0021830.JPG', 'Smola_Skalmen_00000039_20230620T154715Z_G0021832.JPG', 'Smola_Skalmen_00000040_20230620T154716Z_G0021834.JPG', 'Smola_Skalmen_00000041_20230620T154717Z_G0021836.JPG', 'Smola_Skalmen_00000042_20230620T154718Z_G0021838.JPG', 'Smola_Skalmen_00000043_20230620T154719Z_G0021840.JPG', 'Smola_Skalmen_00000044_20230620T154720Z_G0021842.JPG', 'Smola_Skalmen_00000045_20230620T154721Z_G0021844.JPG', 'Smola_Skalmen_00000046_20230620T154722Z_G0021846.JPG', 'Smola_Skalmen_00000047_20230620T154723Z_G0021848.JPG', 'Smola_Skalmen_00000048_20230620T154724Z_G0021850.JPG', 'Smola_Skalmen_00000049_20230620T154725Z_G0021852.JPG']

# %%
output_dir = im_dir / 'TestOutput'
output_dir.mkdir(exist_ok=True)
print('Copying and renaming files...')
for source_file,new_filename in tqdm.tqdm(zip(gdf.ImageFile,new_image_filenames)):
    destination_file = output_dir / new_filename
    #print(f'Source: {source_file}, destination: {destination_file}')
    shutil.copy(source_file,destination_file)
# Out:
# Copying and renaming files...
# 50it [00:00, 277.51it/s]

# %%
updated_gdf = gdf.copy()
updated_gdf.iloc[:,updated_gdf.columns.get_loc('ImageFile')] = new_image_filenames
updated_gdf
# Out:
#                                   Time        Lat       Lng  \
# 36769 2023-06-20 15:46:36.431000+00:00  63.466281  7.765075
# 36779 2023-06-20 15:46:37.423000+00:00  63.466279  7.765101
# 36789 2023-06-20 15:46:38.431000+00:00  63.466277  7.765126
# 36799 2023-06-20 15:46:39.423000+00:00  63.466276  7.765154
# 36809 2023-06-20 15:46:40.431000+00:00  63.466275  7.765180
# 36819 2023-06-20 15:46:41.423000+00:00  63.466274  7.765204
# 36829 2023-06-20 15:46:42.431000+00:00  63.466273  7.765231
# 36839 2023-06-20 15:46:43.423000+00:00  63.466272  7.765259
# 36849 2023-06-20 15:46:44.431000+00:00  63.466271  7.765285
# 36859 2023-06-20 15:46:45.423000+00:00  63.466271  7.765310
# 36869 2023-06-20 15:46:46.431000+00:00  63.466271  7.765337
# 36879 2023-06-20 15:46:47.423000+00:00  63.466270  7.765364
# 36889 2023-06-20 15:46:48.431000+00:00  63.466271  7.765390
# 36899 2023-06-20 15:46:49.423000+00:00  63.466271  7.765416
# 36909 2023-06-20 15:46:50.430000+00:00  63.466272  7.765443
# 36919 2023-06-20 15:46:51.422000+00:00  63.466272  7.765468
# 36929 2023-06-20 15:46:52.430000+00:00  63.466273  7.765495
# 36939 2023-06-20 15:46:53.422000+00:00  63.466273  7.765522
# 36949 2023-06-20 15:46:54.430000+00:00  63.466274  7.765548
# 36959 2023-06-20 15:46:55.422000+00:00  63.466274  7.765573
# 36969 2023-06-20 15:46:56.430000+00:00  63.466275  7.765601
# 36979 2023-06-20 15:46:57.422000+00:00  63.466276  7.765627
# 36989 2023-06-20 15:46:58.430000+00:00  63.466276  7.765652
# 36999 2023-06-20 15:46:59.422000+00:00  63.466276  7.765678
# 37009 2023-06-20 15:47:00.430000+00:00  63.466277  7.765705
# 37020 2023-06-20 15:47:01.518000+00:00  63.466277  7.765733
# 37029 2023-06-20 15:47:02.430000+00:00  63.466277  7.765757
# 37040 2023-06-20 15:47:03.517000+00:00  63.466277  7.765787
# 37049 2023-06-20 15:47:04.429000+00:00  63.466278  7.765809
# 37060 2023-06-20 15:47:05.517000+00:00  63.466278  7.765836
# 37069 2023-06-20 15:47:06.429000+00:00  63.466278  7.765859
# 37080 2023-06-20 15:47:07.517000+00:00  63.466277  7.765888
# 37090 2023-06-20 15:47:08.525000+00:00  63.466277  7.765913
# 37100 2023-06-20 15:47:09.517000+00:00  63.466277  7.765939
# 37110 2023-06-20 15:47:10.525000+00:00  63.466277  7.765964
# 37120 2023-06-20 15:47:11.533000+00:00  63.466277  7.765989
# 37130 2023-06-20 15:47:12.525000+00:00  63.466276  7.766016
# 37140 2023-06-20 15:47:13.533000+00:00  63.466276  7.766043
# 37150 2023-06-20 15:47:14.525000+00:00  63.466276  7.766067
# 37160 2023-06-20 15:47:15.533000+00:00  63.466276  7.766092
# 37170 2023-06-20 15:47:16.525000+00:00  63.466276  7.766118
# 37180 2023-06-20 15:47:17.533000+00:00  63.466275  7.766142
# 37190 2023-06-20 15:47:18.525000+00:00  63.466275  7.766168
# 37200 2023-06-20 15:47:19.532000+00:00  63.466275  7.766195
# 37210 2023-06-20 15:47:20.524000+00:00  63.466275  7.766220
# 37220 2023-06-20 15:47:21.532000+00:00  63.466275  7.766244
# 37230 2023-06-20 15:47:22.524000+00:00  63.466275  7.766270
# 37240 2023-06-20 15:47:23.532000+00:00  63.466275  7.766295
# 37250 2023-06-20 15:47:24.524000+00:00  63.466275  7.766320
# 37260 2023-06-20 15:47:25.532000+00:00  63.466274  7.766346
#
#                                                ImageFile  \
# 36769  Smola_Skalmen_00000000_2023-06-20T15:46:36Z_G0...
# 36779  Smola_Skalmen_00000001_2023-06-20T15:46:37Z_G0...
# 36789  Smola_Skalmen_00000002_2023-06-20T15:46:38Z_G0...
# 36799  Smola_Skalmen_00000003_2023-06-20T15:46:39Z_G0...
# 36809  Smola_Skalmen_00000004_2023-06-20T15:46:40Z_G0...
# 36819  Smola_Skalmen_00000005_2023-06-20T15:46:41Z_G0...
# 36829  Smola_Skalmen_00000006_2023-06-20T15:46:42Z_G0...
# 36839  Smola_Skalmen_00000007_2023-06-20T15:46:43Z_G0...
# 36849  Smola_Skalmen_00000008_2023-06-20T15:46:44Z_G0...
# 36859  Smola_Skalmen_00000009_2023-06-20T15:46:45Z_G0...
# 36869  Smola_Skalmen_00000010_2023-06-20T15:46:46Z_G0...
# 36879  Smola_Skalmen_00000011_2023-06-20T15:46:47Z_G0...
# 36889  Smola_Skalmen_00000012_2023-06-20T15:46:48Z_G0...
# 36899  Smola_Skalmen_00000013_2023-06-20T15:46:49Z_G0...
# 36909  Smola_Skalmen_00000014_2023-06-20T15:46:50Z_G0...
# 36919  Smola_Skalmen_00000015_2023-06-20T15:46:51Z_G0...
# 36929  Smola_Skalmen_00000016_2023-06-20T15:46:52Z_G0...
# 36939  Smola_Skalmen_00000017_2023-06-20T15:46:53Z_G0...
# 36949  Smola_Skalmen_00000018_2023-06-20T15:46:54Z_G0...
# 36959  Smola_Skalmen_00000019_2023-06-20T15:46:55Z_G0...
# 36969  Smola_Skalmen_00000020_2023-06-20T15:46:56Z_G0...
# 36979  Smola_Skalmen_00000021_2023-06-20T15:46:57Z_G0...
# 36989  Smola_Skalmen_00000022_2023-06-20T15:46:58Z_G0...
# 36999  Smola_Skalmen_00000023_2023-06-20T15:46:59Z_G0...
# 37009  Smola_Skalmen_00000024_2023-06-20T15:47:00Z_G0...
# 37020  Smola_Skalmen_00000025_2023-06-20T15:47:01Z_G0...
# 37029  Smola_Skalmen_00000026_2023-06-20T15:47:02Z_G0...
# 37040  Smola_Skalmen_00000027_2023-06-20T15:47:03Z_G0...
# 37049  Smola_Skalmen_00000028_2023-06-20T15:47:04Z_G0...
# 37060  Smola_Skalmen_00000029_2023-06-20T15:47:05Z_G0...
# 37069  Smola_Skalmen_00000030_2023-06-20T15:47:06Z_G0...
# 37080  Smola_Skalmen_00000031_2023-06-20T15:47:07Z_G0...
# 37090  Smola_Skalmen_00000032_2023-06-20T15:47:08Z_G0...
# 37100  Smola_Skalmen_00000033_2023-06-20T15:47:09Z_G0...
# 37110  Smola_Skalmen_00000034_2023-06-20T15:47:10Z_G0...
# 37120  Smola_Skalmen_00000035_2023-06-20T15:47:11Z_G0...
# 37130  Smola_Skalmen_00000036_2023-06-20T15:47:12Z_G0...
# 37140  Smola_Skalmen_00000037_2023-06-20T15:47:13Z_G0...
# 37150  Smola_Skalmen_00000038_2023-06-20T15:47:14Z_G0...
# 37160  Smola_Skalmen_00000039_2023-06-20T15:47:15Z_G0...
# 37170  Smola_Skalmen_00000040_2023-06-20T15:47:16Z_G0...
# 37180  Smola_Skalmen_00000041_2023-06-20T15:47:17Z_G0...
# 37190  Smola_Skalmen_00000042_2023-06-20T15:47:18Z_G0...
# 37200  Smola_Skalmen_00000043_2023-06-20T15:47:19Z_G0...
# 37210  Smola_Skalmen_00000044_2023-06-20T15:47:20Z_G0...
# 37220  Smola_Skalmen_00000045_2023-06-20T15:47:21Z_G0...
# 37230  Smola_Skalmen_00000046_2023-06-20T15:47:22Z_G0...
# 37240  Smola_Skalmen_00000047_2023-06-20T15:47:23Z_G0...
# 37250  Smola_Skalmen_00000048_2023-06-20T15:47:24Z_G0...
# 37260  Smola_Skalmen_00000049_2023-06-20T15:47:25Z_G0...
#
#                        geometry
# 36769  POINT (7.76508 63.46628)
# 36779  POINT (7.76510 63.46628)
# 36789  POINT (7.76513 63.46628)
# 36799  POINT (7.76515 63.46628)
# 36809  POINT (7.76518 63.46627)
# 36819  POINT (7.76520 63.46627)
# 36829  POINT (7.76523 63.46627)
# 36839  POINT (7.76526 63.46627)
# 36849  POINT (7.76528 63.46627)
# 36859  POINT (7.76531 63.46627)
# 36869  POINT (7.76534 63.46627)
# 36879  POINT (7.76536 63.46627)
# 36889  POINT (7.76539 63.46627)
# 36899  POINT (7.76542 63.46627)
# 36909  POINT (7.76544 63.46627)
# 36919  POINT (7.76547 63.46627)
# 36929  POINT (7.76549 63.46627)
# 36939  POINT (7.76552 63.46627)
# 36949  POINT (7.76555 63.46627)
# 36959  POINT (7.76557 63.46627)
# 36969  POINT (7.76560 63.46628)
# 36979  POINT (7.76563 63.46628)
# 36989  POINT (7.76565 63.46628)
# 36999  POINT (7.76568 63.46628)
# 37009  POINT (7.76571 63.46628)
# 37020  POINT (7.76573 63.46628)
# 37029  POINT (7.76576 63.46628)
# 37040  POINT (7.76579 63.46628)
# 37049  POINT (7.76581 63.46628)
# 37060  POINT (7.76584 63.46628)
# 37069  POINT (7.76586 63.46628)
# 37080  POINT (7.76589 63.46628)
# 37090  POINT (7.76591 63.46628)
# 37100  POINT (7.76594 63.46628)
# 37110  POINT (7.76596 63.46628)
# 37120  POINT (7.76599 63.46628)
# 37130  POINT (7.76602 63.46628)
# 37140  POINT (7.76604 63.46628)
# 37150  POINT (7.76607 63.46628)
# 37160  POINT (7.76609 63.46628)
# 37170  POINT (7.76612 63.46628)
# 37180  POINT (7.76614 63.46628)
# 37190  POINT (7.76617 63.46628)
# 37200  POINT (7.76620 63.46628)
# 37210  POINT (7.76622 63.46627)
# 37220  POINT (7.76624 63.46627)
# 37230  POINT (7.76627 63.46627)
# 37240  POINT (7.76630 63.46627)
# 37250  POINT (7.76632 63.46627)
# 37260  POINT (7.76635 63.46627)

# %%
def copy_rename_georeferenced_images(gdf,output_dir,image_filename_base,include_full_path_in_gdf=False):
    """ Copy and rename image files in geodataframe
    
    # Arguments:
    gdf:
        GeoDataFrame with columns "Time" (datetime) and "ImageFile" (pathlib.Path)
        ImageFile paths are assumed to be absolute.
    output_dir:
        Output directory which files will be copied to.
    image_filename_base:
        String with filename base for new filenames.
        Typically location (e.g. 'Smola_Skalmen_) or some other information
        which is common for all images.
    include_full_path_in_gdf:
        Boolean. If True, geodataframe is updated with full path to new files
        If False (default), only filename is inserted in ImagePath column
        in updated geodataframe.

    Images are given new names on the following format:
    <image_filename_base>_<ImageNumber>_<ImageDateTime>_<OriginalFileName>

    # Returns:
    updated_gdf:
        Copy of gdf, with ImageFile updated with 
    """
    # Create new file names based on old filenames and timestamps
    im_paths = gdf.ImageFile
    im_times = gdf.Time
    new_image_filenames = []
    for i,(im_path,im_time) in enumerate(zip(im_paths,im_times)):
        new_image_filename = image_filename_base
        new_image_filename += f'{i:08d}_'
        new_image_filename += im_time.strftime("%Y%m%dT%H%M%SZ_")
        new_image_filename += im_path.name
        new_image_filenames.append(new_image_filename)

    # Create output directory (if not already present), copy and rename files
    output_dir = im_dir / 'TestOutput'
    output_dir.mkdir(exist_ok=True,parents=True)
    print('Copying and renaming files...')
    for source_file,new_filename in tqdm.tqdm(zip(gdf.ImageFile,new_image_filenames)):
        destination_file = output_dir / new_filename
        shutil.copy(source_file,destination_file)

    # Update path to image in geodataframe
    updated_gdf = gdf.copy()
    if include_full_path_in_gdf:
        full_new_image_filenames = [str(output_dir / new_image_filename) for 
                                    new_image_filename in new_image_filenames]
        updated_gdf.iloc[:,updated_gdf.columns.get_loc('ImageFile')] = full_new_image_filenames
    else:
        updated_gdf.iloc[:,updated_gdf.columns.get_loc('ImageFile')] = new_image_filenames
    return updated_gdf
