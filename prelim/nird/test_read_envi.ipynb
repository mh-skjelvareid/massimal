# %%
from massimal import hyspec_io, image_render
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Paths
image_path = Path('/home/mha114/data/massimal/vega_sola/hyperspec/images/2a_rrs/Sound2/Vega_SolaNW_Sound2_Pika_L_17-Crop Wavelengths.bip.hdr')

# %%
(image,wl,rgb_ind,metadata) = hyspec_io.load_envi_image(image_path)

# %%
_ = plt.imshow(image_render.percentile_stretch(image[:,:,rgb_ind]))
