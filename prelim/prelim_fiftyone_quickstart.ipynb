# %%
import fiftyone as fo
import fiftyone.zoo as foz

#dataset = foz.load_zoo_dataset("quickstart")
#session = fo.launch_app(dataset)

# %%
# Handle dataset

# The directory containing the source images
data_path = "/mnt/datadisk/Massimal/Test_Hasty_Annotation_Export/Area"

# The path to the COCO labels JSON file
labels_path = "/mnt/datadisk/Massimal/Test_Hasty_Annotation_Export/Sandsund_20210602_CocoFormat.json"

# Import the dataset
dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=labels_path,
)
# dataset = fo.Dataset.from_dir(
#     dataset_type=fo.types.ImageSegmentationDataset,
#     data_path=data_path,
#     labels_path=labels_path,
# )
# Out:
#  100% |███████████████████| 19/19 [58.6ms elapsed, 0s remaining, 324.4 samples/s]

# %%
fo.types.ImageSegmentationDataset

# %%
# Launch the FiftyOne App in a dedicated browser tab
session = fo.launch_app(dataset,auto=False)
session.open_tab()
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.

# %%
view = dataset.view()
print(view)
# Out:
# Dataset:     2022.06.17.21.07.57
# Media type:  image
# Num samples: 19
# Tags:        []
# Sample fields:
#     id:           fiftyone.core.fields.ObjectIdField
#     filepath:     fiftyone.core.fields.StringField
#     tags:         fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     ground_truth: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
# View stages:
#     ---

# %%
print(dataset)
# Out:
# Name:        2022.06.17.15.09.55
# Media type:  image
# Num samples: 19
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:           fiftyone.core.fields.ObjectIdField
#     filepath:     fiftyone.core.fields.StringField
#     tags:         fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     ground_truth: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)

# %%
print(dataset.head(num_samples=1))
# Out:
# [<Sample: {
#     'id': '62acd26fa0f2fd9d6b218e7d',
#     'media_type': 'image',
#     'filepath': '/mnt/datadisk/Massimal/Test_Hasty_Annotation_Export/Area/Sandsund_May2021_Pika_L_02bil_image.png',
#     'tags': BaseList([]),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 1632,
#         'height': 1116,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '62acd26fa0f2fd9d6b218e7b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Rockweed',
#                 'bounding_box': BaseList([
#                     0.031862745098039214,
#                     0.5232974910394266,
#                     0.8431372549019608,
#                     0.26881720430107525,
#                 ]),
#                 'mask': None,
# ...

# %%
import json

hasty_json = "/mnt/datadisk/Massimal/Test_Hasty_Annotation_Export/20210602_Sandsund_HastyFormat.json"

with open(hasty_json, 'r') as textfile:
    data = textfile.read()

# Parse JSON text into list
ann_class_info = json.loads(data)

# %%
key_list = []
for key in ann_class_info.keys():
    key_list.append(key)

print(key_list)
# Out:
# ['project_name', 'create_date', 'export_format_version', 'export_date', 'label_classes', 'images', 'attributes']

# %%
ann_class_info['images'][12]
# Out:
# {'image_id': '9577c0e8-b8d5-4e7f-9292-84e9e3de154e',
#  'width': 1632,
#  'height': 1116,
#  'image_name': 'Sandsund_May2021_Pika_L_02bil_image.png',
#  'image_mode': 'NRGBA',
#  'dataset_name': 'Area',
#  'image_status': 'DONE',
#  'labels': [{'id': '3f2ee67c-5a85-48cc-aadd-318e72c9279e',
#    'class_name': 'Rockweed',
#    'bbox': [52, 584, 1428, 884],
#    'polygon': None,
#    'mask': [203,
#     5,
#     1578,
#     7,
#     2953,
#     9,
#     2963,
#     3,
#     4269,
#     4,
#     4329,
#     14,
#     4373,
#     3,
#     5644,
#     6,
#     5704,
#     15,
#     5748,
#     5,
#     7020,
#     6,
#     7080,
#     16,
#     7123,
#     6,
#     8392,
#     11,
#     8456,
#     17,
#     8498,
#     8,
#     9766,
#     13,
#     9833,
#     4,
#     9840,
#     10,
#     9872,
#     11,
#     11141,
#     17,
#     11216,
#     11,
#     11245,
#     15,
#     12517,
#     18,
#     12592,
#     11,
#     12619,
#     18,
#     12663,
#     6,
#     13893,
#     18,
# ...

# %%
ann_class_info.keys()
# Out:
# dict_keys(['project_name', 'create_date', 'export_format_version', 'export_date', 'label_classes', 'images', 'attributes'])

# %%
ann_class_info['project_name']
# Out:
# '20210602_Sandsund'
